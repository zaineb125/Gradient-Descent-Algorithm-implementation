# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import pandas as pd

# %%
X,y=make_blobs(n_samples=100,n_features=2,centers=2,random_state=0)
y=y.reshape((y.shape[0],1))

print('dimension de X : ',X.shape)
print('dimension de y : ',y.shape)

plt.scatter(X[:,0],X[:,1],c=y,cmap='summer')
plt.show()
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f173b9fb5328> in <module>
# ----> 1 X,y=make_blobs(n_samples=100,n_features=2,centers=2,random_state=0)
#       2 y=y.reshape((y.shape[0],1))
#       3
#       4 print('dimension de X : ',X.shape)
#       5 print('dimension de y : ',y.shape)
#
# NameError: name 'make_blobs' is not defined

# %%
def initialisation(X):
    W = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return (W, b)

# %%
w,b=initialisation(X)

# %%
def model(X, W, b):
    Z = X.dot(W) + b
    # print(Z.min())
    A = 1 / (1 + np.exp(-Z))
    return A

# %%
A=model(X,w,b)
A.shape
# Out:
# (100, 1)

# %%
def log_loss(A, y):
    epsilon = 1e-15
    return 1 / len(y) * np.sum(-y * np.log(A + epsilon) - (1 - y) * np.log(1 - A+ epsilon))

# %%
def gradients(A, X, y):
    dW = 1 / len(y) * np.dot(X.T, A - y)
    db = 1 / len(y) * np.sum(A - y)
    return (dW, db)

# %%
dw ,db=gradients(A,X,y)
dw.shape

# %%
def update(dW, db, W, b, learning_rate):
    W = W - learning_rate * dW
    b = b - learning_rate * db
    return (W, b)

# %%
def predict(X, W, b):
    A = model(X, W, b)
    # print(A)
    return A >= 0.5

# %%
from sklearn.metrics import accuracy_score

# %%
def artificial_neuron(X_train,y_train,X_test,y_test,learning_rate=0.1,n_iter=100):
    W,b = initialisation(X_train)
    
    train_loss=[]
    train_acc=[]
    
    test_loss=[]
    test_acc=[]
    
    for i in range(n_iter):
        A=model(X_train,W,b)
        if i%10 ==0 :
            #train
            train_loss.append(log_loss(A,y_train))
            y_pred=predict(X_train,W,b)
            train_acc.append(accuracy_score(y_train,y_pred))
            #test
            A_test=model(X_test,W,b)
            test_loss.append(log_loss(A_test,y_test))
            y_pred=predict(X_test,W,b)
            train_acc.append(accuracy_score(y_test,y_pred))
            
        dw,db=gradients(A,X_train,y_train)
        W,b=update(dw,db,W,b,learning_rate)
    
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='train loss')
    plt.plot(test_loss, label='test loss')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='train acc')
    plt.plot(test_acc, label='test acc')
    plt.legend()
    plt.show()
    return (W,b)

# %%
w,b=artificial_neuron(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d95041c6dc99> in <module>
# ----> 1 w,b=artificial_neuron(X,y)
#
# NameError: name 'X' is not defined

# %%
new_plant=np.array([2,1])
x0=np.linspace(-1,4,100) #de x=-1 à x=4 avec 100 points
x1=(-w[0]*x0 -b)/w[1]
plt.scatter(X[:,0],X[:,1],c=y,cmap='summer')
plt.scatter(new_plant[0],new_plant[1],c='r')
plt.plot(x0,x1,c='orange',lw=3)
plt.show()
predict(new_plant,w,b)
# Out:
# array([False])

# %% [markdown]
# # Application Chat vs Chien

# %%
from utilities import *

# %%
X_train ,y_train ,X_test,y_test=load_data()

# %%
print(X_train.shape)
print(y_train.shape)
print(np.unique(y_train, return_counts=True))
# Out:
# (1000, 64, 64)
# (1000, 1)
# (array([0., 1.]), array([500, 500], dtype=int64))

# %%
print(X_test.shape)
print(y_test.shape)
print(np.unique(y_test, return_counts=True))
# Out:
# (200, 64, 64)
# (200, 1)
# (array([0., 1.]), array([100, 100], dtype=int64))

# %%
plt.figure(figsize=(16, 8))
for i in range(1, 10):
    plt.subplot(4, 5, i)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(y_train[i])
    plt.tight_layout()
plt.show()
# Out:
# C:\Users\zaine\anaconda3\lib\site-packages\matplotlib\text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# #  Entrainement du Modele

# %%
X_train_reshape = X_train.reshape(X_train.shape[0], -1) / X_train.max()
X_train_reshape.shape
# Out:
# (1000, 4096)

# %%
X_test_reshape = X_test.reshape(X_test.shape[0], -1) / X_train.max()
X_test_reshape.shape
# Out:
# (200, 4096)

# %%
W, b = artificial_neuron(X_train_reshape, y_train, X_test_reshape, y_test, learning_rate = 0.01, n_iter=10000)

# %% [markdown]
# On a un modele d'overfitting => plus d'errer sur le test set que sur le train set
# capacité a generalise n'est pas bonne
# Comment regler ce probleme ?
# On doit fournir plus d'image a notre machine .
# On a un grand decalage entre le nombre de photo et le nombre de variable => phenomene de fleo de dimension
